# %%
import numpy as np
import tensorflow as tf 
from tensorflow import keras
import matplotlib.pyplot as plt
from scipy import interpolate
from datetime import datetime
import os
import json
import pickle
# import tensorflow_addons as tfa

# %%
def upsample(dim_new, arr):
    dim_old = np.shape(arr)[0]
    assert np.shape(arr)[0] == np.shape(arr)[1]
    x = np.arange(dim_old)
    f = interpolate.interp2d(x, x, arr, kind='linear')
    xnew = np.linspace(0, dim_old, dim_new)
    ynew = np.linspace(0, dim_old, dim_new)
    return f(xnew, ynew)

def show_digits(X, y, i):
    fig, ax = plt.subplots(1, len(i), sharex=True)
    for k, j in enumerate(i):
        ax[k].imshow(X[j])
        ax[k].set_title(y[j])
        ax[k].axis('off')
    plt.tight_layout()
    plt.show()
    
def mse(x, y):
    x = np.reshape(x, (-1,))
    y = np.reshape(y, (-1,))
    return np.mean((x - y)**2)

def mae(x, y):
    x = np.reshape(x, (-1,))
    y = np.reshape(y, (-1,))
    return np.mean(np.abs(x - y))

# %% [markdown]
# # Data Generation
# Instead of dividing into two train/validation/test sets as before for the logistic regression and subsequent classifiers, now we just do one split! As such, we will use the default splitting on MNIST.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train, x_test = x_train[..., np.newaxis] / 255., x_test[..., np.newaxis] / 255.
y_train_old, y_test_old = y_train, y_test
y_train, y_test = y_train.astype(float) / 10.,  y_test.astype(float) / 10.
y_train, y_test = np.random.binomial(1, y_train), np.random.binomial(1, y_test)

# %%
show_digits(x_train, y_train, range(10))
show_digits(x_test, y_test, range(10))

# %%
fig, ax = plt.subplots(1, 10, sharey=True, figsize=(14, 2))
for i in range(10):
    ax[i].hist(y_train[y_train_old == i])
    ax[i].set_title("N=" + str(i))
plt.tight_layout()

fig, ax = plt.subplots(1, 10, sharey=True, figsize=(14, 2))
for i in range(10):
    ax[i].hist(y_test[y_test_old == i])
    ax[i].set_title("N=" + str(i))
plt.tight_layout()

# %% [markdown]
# Lastly, we need to upsample the data to make it compatible with the default ResNets and check that they match the digits we printed earlier.

# %%
x_train_new = np.empty((len(x_train), 32, 32, 1))
for i, img in enumerate(x_train):
    x_train_new[i] = upsample(32, img).reshape(32, 32, 1)
    
x_test_new = np.empty((len(x_test), 32, 32, 1))
for i, img in enumerate(x_test):
    x_test_new[i] = upsample(32, img).reshape(32, 32, 1)
    
x_train, x_test = x_train_new, x_test_new
show_digits(x_train, y_train, range(10))
show_digits(x_test, y_test, range(10))

# %% [markdown]
# # Load the Model
# We will load the smallest ResNet that tensorflow has on offer and then perform a quick test to show that we can transfer the weights from one to another.

# %%
print(len(tf.keras.applications.ResNet101(include_top=False, weights=None).layers),
      len(tf.keras.applications.ResNet101V2(include_top=False, weights=None).layers),
      len(tf.keras.applications.ResNet152(include_top=False, weights=None).layers),
      len(tf.keras.applications.ResNet152V2(include_top=False, weights=None).layers),
      len(tf.keras.applications.ResNet50(include_top=False, weights=None).layers),
      len(tf.keras.applications.ResNet50V2(include_top=False, weights=None).layers))
# Out:
# 345 377 515 564 175 190

# %%
model_name = "small_resnet_" + datetime.now().strftime("%m-%d-%Y_%H:%M:%S")
print("Model name:", model_name)
os.mkdir(model_name)
os.mkdir(model_name + "_new")
batch_size = 128
small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')
# Out:
# Model name: small_resnet_05-21-2021_13:50:20

# %% [markdown]
# My understanding is that the V2 architectures generally outperform the V1 achitectures as they allow for gradients to propagate more freely to the block pointed to by the skip connection as they are not subjected to the block's activation before being added to it, so we will use `Resnet50V2`.

# %%
# class CustomCallback(keras.callbacks.Callback):
#     def __init__(self, name):
#         f = open(name + "/train.txt", "x")
#         f.close()
#         f = open(name + "/test.txt", "x")
#         f.close()
#         self.train_mse = []
#         self.test_mse = []
        
#     def on_batch_end(self, batch, logs=None):
#         p_train = self.model.predict(x_train[batch * batch_size : (batch + 1) * batch_size])
#         mse_train = mse(p_train, y_train_old[batch * batch_size : (batch + 1) * batch_size] / 10.)
#         self.train_mse.append(mse_train)
        
#     def on_epoch_end(self, epoch, logs=None):
#         p_test = self.model.predict(x_test)
#         mse_test = mse(p_test, y_test_old / 10.)
#         self.test_mse.append(mse_test)
        
#         mse_train = np.mean(self.train_mse)
#         self.train_mse = []

#         with open(model_name + "/train.txt", "a") as f:
#             f.write(str(mse_train) + " ")

#         with open(model_name + "/test.txt", "a") as f:
#             f.write(str(mse_test) + " ")
            
#         print("Epoch " + str(epoch) + " ending p* train MSE: " + str(mse_train))
#         print("Epoch " + str(epoch) + " ending p* test MSE: " + str(mse_test))

# %%
# Get model tops
top2 = keras.models.Sequential([
    keras.layers.Dense(256, activation='tanh', kernel_initializer=keras.initializers.RandomUniform()),
    keras.layers.Dense(128, activation='tanh', kernel_initializer=keras.initializers.RandomUniform()),
    keras.layers.Dense(1, activation='sigmoid', kernel_initializer=keras.initializers.RandomUniform())
], name='w_new')

top1 = keras.models.Sequential([
    keras.layers.Dense(256, activation='tanh', kernel_initializer=keras.initializers.RandomUniform()),
    keras.layers.Dense(128, activation='tanh', kernel_initializer=keras.initializers.RandomUniform()),
    keras.layers.Dense(1, activation='sigmoid', kernel_initializer=keras.initializers.RandomUniform())
], name='w_hat')


# opt = tfa.optimizers.SGDW(
#     weight_decay = 5e-4 * batch_size,
#     momentum = 0.9)

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# Now that the model has been loaded, we will test two iterations of our training loop showing the MSE with p* after each iteration. To do this, we should (a) write a callback to compute the MSE for the fhat model and (b) do a test to make sure that the w_new * hhat model loads the correct weights from its two sources.

# %%
# Scheduler and opt taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
s = np.concatenate((np.linspace(0, 0.1, 16)[1:], np.linspace(0.1, 0.005, 16)[1:], np.linspace(0, 0.005, 7)[-1:1:-1]))
n = len(s)
def schedule_outer(epoch, lr):
    if i > n:
        return lr * 0.96
    else:
        return s[i]
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

def schedule_inner(epoch, lr):
    return lr * 0.96
lr_scheduler_inner = tf.keras.callbacks.LearningRateScheduler(schedule_inner, verbose=1)


n_epochs = 2
hists1 = []
hists2 = []

for i in range(n_epochs):
    fhat_model.trainable = True
    fhat_model.summary()
    hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=1, batch_size=batch_size, 
                                 validation_data=(x_test, y_test_old / 10.), shuffle=False,
                                 callbacks=[lr_scheduler_outer,]))

    model = keras.Sequential()
    model.add(fhat_model.layers[0])
    fhat_model.trainable = False
    model.add(top2)

    model.compile(optimizer=keras.optimizers.SGD(momentum=0.9),
                  loss=keras.losses.BinaryCrossentropy(),
                  metrics=[keras.metrics.MeanSquaredError()])
    model.summary()

    hists2.append(model.fit(x=x_train, y=y_train_old / 10., epochs=5, batch_size=batch_size, shuffle=False,
                            validation_data=(x_test, y_test_old / 10.), callbacks=[lr_scheduler_inner,]))
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006666666666666667.
# 469/469 [==============================] - 144s 303ms/step - loss: 0.6083 - mean_squared_error: 0.2119 - binary_accuracy: 0.6451 - val_loss: 0.5474 - val_mean_squared_error: 0.0214 - val_binary_accuracy: 0.0976
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_new (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 557,569
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 113ms/step - loss: 0.5426 - mean_squared_error: 0.0207 - val_loss: 0.5345 - val_mean_squared_error: 0.0183
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.5159 - mean_squared_error: 0.0104 - val_loss: 0.5309 - val_mean_squared_error: 0.0170
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 56s 120ms/step - loss: 0.5139 - mean_squared_error: 0.0097 - val_loss: 0.5295 - val_mean_squared_error: 0.0165
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 55s 117ms/step - loss: 0.5126 - mean_squared_error: 0.0093 - val_loss: 0.5288 - val_mean_squared_error: 0.0163
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.5116 - mean_squared_error: 0.0089 - val_loss: 0.5283 - val_mean_squared_error: 0.0161
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.013333333333333334.
# 469/469 [==============================] - 135s 287ms/step - loss: 0.5156 - mean_squared_error: 0.1735 - binary_accuracy: 0.7360 - val_loss: 0.5168 - val_mean_squared_error: 0.0109 - val_binary_accuracy: 0.0977
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_new (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 557,569
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 56s 116ms/step - loss: 0.5136 - mean_squared_error: 0.0099 - val_loss: 0.5217 - val_mean_squared_error: 0.0124
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.5136 - mean_squared_error: 0.0099 - val_loss: 0.5217 - val_mean_squared_error: 0.0124
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.5136 - mean_squared_error: 0.0099 - val_loss: 0.5217 - val_mean_squared_error: 0.0124
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.5136 - mean_squared_error: 0.0099 - val_loss: 0.5217 - val_mean_squared_error: 0.0124
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.5136 - mean_squared_error: 0.0099 - val_loss: 0.5217 - val_mean_squared_error: 0.0124

# %% [markdown]
# Merge hist1 and hist2 so we can see what's going on

# %%
total_hist1 = dict()
total_hist2 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
for key in hists2[0].history.keys():
    current_values = [] 
    for hist_dict in hists2:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist2[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist2['loss'], label='train')
ax[0].plot(total_hist2['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist2['mean_squared_error'], label='train')
ax[1].plot(total_hist2['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

print(mse(fhat_model.predict(x_test), y_test_old / 10.))
print(mse(model.predict(x_test), y_test_old / 10.))

print(mae(fhat_model.predict(x_test), y_test_old / 10.))
print(mae(model.predict(x_test), y_test_old / 10.))
# Out:
# [0.7255363  0.05007176 0.09210654 ... 0.35326755 0.52741355 0.5531826 ]
# 0.015188293555786398
# [0.6427675  0.0537303  0.106712   ... 0.49919918 0.50649357 0.4890999 ]
# 0.012382541388373877
# 0.07751189742453397
# 0.06795441972527189

# %% [markdown]
# Some observations:
# - It appears that we're already overfitting in epoch 2 of the first global epoch of training--does this mean we should decrease the size of the two top layers? Try adding dropout to prevent overfitting? Although, this may not actually be overfitting because the ResNet uses regularization techniques that make training error not equal to evaluation error
# - After the first round of global training, the MSE of the inner training loop stays fixed--I want to see if adding a ReduceLROnPlateau callback will help. Alternatively, we could try making the exponential decay larger.
# - It looks like the modified outer learning rate scheduler is working great!
# - Should we be resetting the top layer each time?

# %% [markdown]
# # New Model with ReduceLROnPlateau Callback
# Analysis: resetting the new top helped a TON. ReducceLROnPlateau Callback doesn't do much, but will be useful when we train for longer periods of time. Overfitting is clearly still an issue though, so we will try dropout next.

# %%
# Model name and create resnet
model_name = "small_resnet_" + datetime.now().strftime("%m-%d-%Y_%H:%M:%S")
print("Model name:", model_name)
os.mkdir(model_name)
os.mkdir(model_name + "_new")
batch_size = 128
small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(256, activation='tanh', kernel_initializer=keras.initializers.RandomUniform()),
    keras.layers.Dense(128, activation='tanh', kernel_initializer=keras.initializers.RandomUniform()),
    keras.layers.Dense(1, activation='sigmoid', kernel_initializer=keras.initializers.RandomUniform())
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


# Scheduler taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
s = np.concatenate((np.linspace(0, 0.1, 16)[1:], np.linspace(0.1, 0.005, 16)[1:], np.linspace(0, 0.005, 7)[-1:1:-1]))
n = len(s)
def schedule_outer(epoch, lr):
    if i > n:
        return lr * 0.96
    else:
        return s[i]
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

def schedule_inner(epoch, lr):
    return lr * 0.96
lr_scheduler_inner = tf.keras.callbacks.LearningRateScheduler(schedule_inner, verbose=1)


lr_reduce = keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_squared_error', factor=0.1, patience=1, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)


n_epochs = 2
hists1 = []
hists2 = []

for i in range(n_epochs):
    fhat_model.trainable = True
    fhat_model.summary()
    hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=1, batch_size=batch_size, 
                                 validation_data=(x_test, y_test_old / 10.), shuffle=False,
                                 callbacks=[lr_scheduler_outer,]))

    model = keras.Sequential()
    model.add(fhat_model.layers[0])
    fhat_model.trainable = False
    
    top2 = keras.models.Sequential([
            keras.layers.Dense(256, activation='tanh', kernel_initializer=keras.initializers.RandomUniform()),
            keras.layers.Dense(128, activation='tanh', kernel_initializer=keras.initializers.RandomUniform()),
            keras.layers.Dense(1, activation='sigmoid', kernel_initializer=keras.initializers.RandomUniform())
        ], name='w_new')
    
    model.add(top2)

    model.compile(optimizer=keras.optimizers.SGD(momentum=0.9),
                  loss=keras.losses.BinaryCrossentropy(),
                  metrics=[keras.metrics.MeanSquaredError()])
    model.summary()

    hists2.append(model.fit(x=x_train, y=y_train_old / 10., epochs=5, batch_size=batch_size, shuffle=False,
                            validation_data=(x_test, y_test_old / 10.), callbacks=[lr_scheduler_inner, lr_reduce,]))

total_hist1 = dict()
total_hist2 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
for key in hists2[0].history.keys():
    current_values = [] 
    for hist_dict in hists2:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist2[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist2['loss'], label='train')
ax[0].plot(total_hist2['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist2['mean_squared_error'], label='train')
ax[1].plot(total_hist2['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

print(mse(fhat_model.predict(x_test), y_test_old / 10.))
print(mse(model.predict(x_test), y_test_old / 10.))

print(mae(fhat_model.predict(x_test), y_test_old / 10.))
print(mae(model.predict(x_test), y_test_old / 10.))
# Out:
# Model name: small_resnet_05-21-2021_15:37:00
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006666666666666667.
# 469/469 [==============================] - 142s 298ms/step - loss: 0.6101 - mean_squared_error: 0.2127 - binary_accuracy: 0.6420 - val_loss: 0.5257 - val_mean_squared_error: 0.0140 - val_binary_accuracy: 0.0976
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_new (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 557,569
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 60s 121ms/step - loss: 0.5456 - mean_squared_error: 0.0221 - val_loss: 0.5237 - val_mean_squared_error: 0.0141
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 54s 116ms/step - loss: 0.5151 - mean_squared_error: 0.0101 - val_loss: 0.5214 - val_mean_squared_error: 0.0133
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 54s 115ms/step - loss: 0.5132 - mean_squared_error: 0.0094 - val_loss: 0.5204 - val_mean_squared_error: 0.0130
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 54s 115ms/step - loss: 0.5119 - mean_squared_error: 0.0090 - val_loss: 0.5199 - val_mean_squared_error: 0.0129
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.5110 - mean_squared_error: 0.0087 - val_loss: 0.5195 - val_mean_squared_error: 0.0127
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.013333333333333334.
# 469/469 [==============================] - 138s 292ms/step - loss: 0.5155 - mean_squared_error: 0.1735 - binary_accuracy: 0.7359 - val_loss: 0.5112 - val_mean_squared_error: 0.0083 - val_binary_accuracy: 0.0977
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_new (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 557,569
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 55s 115ms/step - loss: 0.5290 - mean_squared_error: 0.0154 - val_loss: 0.5133 - val_mean_squared_error: 0.0098
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.5037 - mean_squared_error: 0.0059 - val_loss: 0.5113 - val_mean_squared_error: 0.0091
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.5026 - mean_squared_error: 0.0055 - val_loss: 0.5102 - val_mean_squared_error: 0.0087
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.5019 - mean_squared_error: 0.0053 - val_loss: 0.5095 - val_mean_squared_error: 0.0084
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.5014 - mean_squared_error: 0.0051 - val_loss: 0.5089 - val_mean_squared_error: 0.0082

# %% [markdown]
# # Try L2 regularization (to reduce overfitting)

# %%
# Model name and create resnet
# model_name = "small_resnet_" + datetime.now().strftime("%m-%d-%Y_%H:%M:%S")
# print("Model name:", model_name)
# os.mkdir(model_name)
# os.mkdir(model_name + "_new")
batch_size = 128
small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(256, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


# Scheduler taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
s = np.concatenate((np.linspace(0, 0.1, 16)[1:], np.linspace(0.1, 0.005, 16)[1:], np.linspace(0, 0.005, 7)[-1:1:-1]))
n = len(s)
def schedule_outer(epoch, lr):
    if i > n:
        return lr * 0.96
    else:
        return s[i]
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

def schedule_inner(epoch, lr):
    return lr * 0.96
lr_scheduler_inner = tf.keras.callbacks.LearningRateScheduler(schedule_inner, verbose=1)


lr_reduce = keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_squared_error', factor=0.1, patience=1, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)


n_epochs = 2
hists1 = []
hists2 = []

for i in range(n_epochs):
    fhat_model.trainable = True
    fhat_model.summary()
    hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=1, batch_size=batch_size, 
                                 validation_data=(x_test, y_test_old / 10.), shuffle=False,
                                 callbacks=[lr_scheduler_outer,]))

    model = keras.Sequential()
    model.add(fhat_model.layers[0])
    fhat_model.trainable = False
    
    top2 = keras.models.Sequential([
        keras.layers.Dense(256, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dense(128, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dense(1, activation='sigmoid', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001))
    ], name='w_hat')
    
    model.add(top2)

    model.compile(optimizer=keras.optimizers.SGD(momentum=0.9),
                  loss=keras.losses.BinaryCrossentropy(),
                  metrics=[keras.metrics.MeanSquaredError()])
    model.summary()

    hists2.append(model.fit(x=x_train, y=y_train_old / 10., epochs=5, batch_size=batch_size, shuffle=False,
                            validation_data=(x_test, y_test_old / 10.), callbacks=[lr_scheduler_inner, lr_reduce,]))

total_hist1 = dict()
total_hist2 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
for key in hists2[0].history.keys():
    current_values = [] 
    for hist_dict in hists2:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist2[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist2['loss'], label='train')
ax[0].plot(total_hist2['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist2['mean_squared_error'], label='train')
ax[1].plot(total_hist2['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

print(mse(fhat_model.predict(x_test), y_test_old / 10.))
print(mse(model.predict(x_test), y_test_old / 10.))

print(mae(fhat_model.predict(x_test), y_test_old / 10.))
print(mae(model.predict(x_test), y_test_old / 10.))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006666666666666667.
# 469/469 [==============================] - 138s 291ms/step - loss: 1.0681 - mean_squared_error: 0.2103 - binary_accuracy: 0.6510 - val_loss: 0.9908 - val_mean_squared_error: 0.0150 - val_binary_accuracy: 0.0979
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 557,569
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 55s 115ms/step - loss: 1.0085 - mean_squared_error: 0.0214 - val_loss: 1.0060 - val_mean_squared_error: 0.0207
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 53s 114ms/step - loss: 0.9792 - mean_squared_error: 0.0097 - val_loss: 1.0023 - val_mean_squared_error: 0.0191
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 54s 115ms/step - loss: 0.9776 - mean_squared_error: 0.0091 - val_loss: 1.0004 - val_mean_squared_error: 0.0182
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 53s 114ms/step - loss: 0.9767 - mean_squared_error: 0.0087 - val_loss: 0.9992 - val_mean_squared_error: 0.0176
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 53s 114ms/step - loss: 0.9760 - mean_squared_error: 0.0084 - val_loss: 0.9983 - val_mean_squared_error: 0.0171
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.013333333333333334.
# 469/469 [==============================] - 141s 300ms/step - loss: 0.9792 - mean_squared_error: 0.1735 - binary_accuracy: 0.7358 - val_loss: 0.9736 - val_mean_squared_error: 0.0085 - val_binary_accuracy: 0.0980
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 557,569
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 113ms/step - loss: 0.9948 - mean_squared_error: 0.0156 - val_loss: 0.9886 - val_mean_squared_error: 0.0132
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 56s 118ms/step - loss: 0.9685 - mean_squared_error: 0.0054 - val_loss: 0.9865 - val_mean_squared_error: 0.0123
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 55s 116ms/step - loss: 0.9675 - mean_squared_error: 0.0050 - val_loss: 0.9857 - val_mean_squared_error: 0.0119
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 54s 115ms/step - loss: 0.9670 - mean_squared_error: 0.0048 - val_loss: 0.9852 - val_mean_squared_error: 0.0116
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 55s 117ms/step - loss: 0.9667 - mean_squared_error: 0.0046 - val_loss: 0.9847 - val_mean_squared_error: 0.0114
# 0.013451509622448461
# 0.01135015826353481
# 0.07111631840646268
# 0.061415813623620204

# %% [markdown]
# # Add Dropout

# %%
# Model name and create resnet
# model_name = "small_resnet_" + datetime.now().strftime("%m-%d-%Y_%H:%M:%S")
# print("Model name:", model_name)
# os.mkdir(model_name)
# os.mkdir(model_name + "_new")
batch_size = 128
small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(256, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


# Scheduler taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
s = np.concatenate((np.linspace(0, 0.1, 16)[1:], np.linspace(0.1, 0.005, 16)[1:], np.linspace(0, 0.005, 7)[-1:1:-1]))
n = len(s)
def schedule_outer(epoch, lr):
    if i > n:
        return lr * 0.96
    else:
        return s[i]
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

def schedule_inner(epoch, lr):
    return lr * 0.96
lr_scheduler_inner = tf.keras.callbacks.LearningRateScheduler(schedule_inner, verbose=1)


lr_reduce = keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_squared_error', factor=0.1, patience=1, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)


n_epochs = 2
hists1 = []
hists2 = []

for i in range(n_epochs):
    fhat_model.trainable = True
    fhat_model.summary()
    hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=1, batch_size=batch_size, 
                                 validation_data=(x_test, y_test_old / 10.), shuffle=False,
                                 callbacks=[lr_scheduler_outer,]))

    model = keras.Sequential()
    model.add(fhat_model.layers[0])
    fhat_model.trainable = False
    
    top2 = keras.models.Sequential([
        keras.layers.Dense(256, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(128, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation='sigmoid', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001))
    ], name='w_hat')
    
    model.add(top2)

    model.compile(optimizer=keras.optimizers.SGD(momentum=0.9),
                  loss=keras.losses.BinaryCrossentropy(),
                  metrics=[keras.metrics.MeanSquaredError()])
    model.summary()

    hists2.append(model.fit(x=x_train, y=y_train_old / 10., epochs=5, batch_size=batch_size, shuffle=False,
                            validation_data=(x_test, y_test_old / 10.), callbacks=[lr_scheduler_inner, lr_reduce,]))

total_hist1 = dict()
total_hist2 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
for key in hists2[0].history.keys():
    current_values = [] 
    for hist_dict in hists2:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist2[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist2['loss'], label='train')
ax[0].plot(total_hist2['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist2['mean_squared_error'], label='train')
ax[1].plot(total_hist2['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

print(mse(fhat_model.predict(x_test), y_test_old / 10.))
print(mse(model.predict(x_test), y_test_old / 10.))

print(mae(fhat_model.predict(x_test), y_test_old / 10.))
print(mae(model.predict(x_test), y_test_old / 10.))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006666666666666667.
# 469/469 [==============================] - 143s 300ms/step - loss: 1.0962 - mean_squared_error: 0.2224 - binary_accuracy: 0.6242 - val_loss: 1.0100 - val_mean_squared_error: 0.0229 - val_binary_accuracy: 0.0978
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 557,569
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 57s 120ms/step - loss: 1.0350 - mean_squared_error: 0.0324 - val_loss: 1.0220 - val_mean_squared_error: 0.0277
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 54s 114ms/step - loss: 0.9970 - mean_squared_error: 0.0167 - val_loss: 1.0220 - val_mean_squared_error: 0.0278
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.0009215999394655228.
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.00088473591953516.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.9954 - mean_squared_error: 0.0161 - val_loss: 1.0191 - val_mean_squared_error: 0.0265
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.000849346462637186.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.9949 - mean_squared_error: 0.0159 - val_loss: 1.0184 - val_mean_squared_error: 0.0262
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000815372597426176.
# 469/469 [==============================] - 54s 116ms/step - loss: 0.9951 - mean_squared_error: 0.0160 - val_loss: 1.0187 - val_mean_squared_error: 0.0263
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 8.153726230375469e-05.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 24,070,657
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.013333333333333334.
# 469/469 [==============================] - 138s 293ms/step - loss: 0.9903 - mean_squared_error: 0.1780 - binary_accuracy: 0.7262 - val_loss: 0.9840 - val_mean_squared_error: 0.0125 - val_binary_accuracy: 0.0976
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 557569
# =================================================================
# Total params: 24,116,097
# Trainable params: 557,569
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 113ms/step - loss: 1.0098 - mean_squared_error: 0.0222 - val_loss: 1.0004 - val_mean_squared_error: 0.0191
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.9791 - mean_squared_error: 0.0100 - val_loss: 0.9959 - val_mean_squared_error: 0.0173
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.9777 - mean_squared_error: 0.0095 - val_loss: 0.9946 - val_mean_squared_error: 0.0167
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.9771 - mean_squared_error: 0.0092 - val_loss: 0.9931 - val_mean_squared_error: 0.0161
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.9765 - mean_squared_error: 0.0090 - val_loss: 0.9919 - val_mean_squared_error: 0.0156
# 0.0178179245221316
# 0.015640554061853135
# 0.0857768898832053
# 0.08001011188706383

# %% [markdown]
# # New Model with Fewer Neurons in Dense Layers

# %%
# Model name and create resnet
# model_name = "small_resnet_" + datetime.now().strftime("%m-%d-%Y_%H:%M:%S")
# print("Model name:", model_name)
# os.mkdir(model_name)
# os.mkdir(model_name + "_new")
batch_size = 128
small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


# Scheduler taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
s = np.concatenate((np.linspace(0, 0.1, 16)[1:], np.linspace(0.1, 0.005, 16)[1:], np.linspace(0, 0.005, 7)[-1:1:-1]))
n = len(s)
def schedule_outer(epoch, lr):
    if i > n:
        return lr * 0.96
    else:
        return s[i]
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

def schedule_inner(epoch, lr):
    return lr * 0.96
lr_scheduler_inner = tf.keras.callbacks.LearningRateScheduler(schedule_inner, verbose=1)


lr_reduce = keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_squared_error', factor=0.1, patience=1, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)


n_epochs = 2
hists1 = []
hists2 = []

for i in range(n_epochs):
    fhat_model.trainable = True
    fhat_model.summary()
    hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=1, batch_size=batch_size, 
                                 validation_data=(x_test, y_test_old / 10.), shuffle=False,
                                 callbacks=[lr_scheduler_outer,]))

    model = keras.Sequential()
    model.add(fhat_model.layers[0])
    fhat_model.trainable = False
    
    top2 = keras.models.Sequential([
        keras.layers.Dense(128, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(64, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation='sigmoid', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001))
    ], name='w_hat')
    
    model.add(top2)

    model.compile(optimizer=keras.optimizers.SGD(momentum=0.9),
                  loss=keras.losses.BinaryCrossentropy(),
                  metrics=[keras.metrics.MeanSquaredError()])
    model.summary()

    hists2.append(model.fit(x=x_train, y=y_train_old / 10., epochs=5, batch_size=batch_size, shuffle=False,
                            validation_data=(x_test, y_test_old / 10.), callbacks=[lr_scheduler_inner, lr_reduce,]))

total_hist1 = dict()
total_hist2 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
for key in hists2[0].history.keys():
    current_values = [] 
    for hist_dict in hists2:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist2[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist2['loss'], label='train')
ax[0].plot(total_hist2['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist2['mean_squared_error'], label='train')
ax[1].plot(total_hist2['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

print(mse(fhat_model.predict(x_test), y_test_old / 10.))
print(mse(model.predict(x_test), y_test_old / 10.))

print(mae(fhat_model.predict(x_test), y_test_old / 10.))
print(mae(model.predict(x_test), y_test_old / 10.))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006666666666666667.
# 469/469 [==============================] - 141s 296ms/step - loss: 0.8876 - mean_squared_error: 0.2352 - binary_accuracy: 0.5785 - val_loss: 0.8244 - val_mean_squared_error: 0.0448 - val_binary_accuracy: 0.0977
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 55s 114ms/step - loss: 0.8228 - mean_squared_error: 0.0436 - val_loss: 0.8063 - val_mean_squared_error: 0.0372
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 55s 116ms/step - loss: 0.7658 - mean_squared_error: 0.0192 - val_loss: 0.8055 - val_mean_squared_error: 0.0368
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 54s 114ms/step - loss: 0.7628 - mean_squared_error: 0.0181 - val_loss: 0.8049 - val_mean_squared_error: 0.0366
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7617 - mean_squared_error: 0.0177 - val_loss: 0.8022 - val_mean_squared_error: 0.0354
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7605 - mean_squared_error: 0.0173 - val_loss: 0.8039 - val_mean_squared_error: 0.0361
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0008153726346790791.
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.013333333333333334.
# 469/469 [==============================] - 135s 288ms/step - loss: 0.7566 - mean_squared_error: 0.1788 - binary_accuracy: 0.7264 - val_loss: 0.7498 - val_mean_squared_error: 0.0138 - val_binary_accuracy: 0.0978
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 113ms/step - loss: 0.7864 - mean_squared_error: 0.0278 - val_loss: 0.7587 - val_mean_squared_error: 0.0170
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7432 - mean_squared_error: 0.0104 - val_loss: 0.7568 - val_mean_squared_error: 0.0163
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 55s 117ms/step - loss: 0.7416 - mean_squared_error: 0.0098 - val_loss: 0.7558 - val_mean_squared_error: 0.0158
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 55s 117ms/step - loss: 0.7408 - mean_squared_error: 0.0095 - val_loss: 0.7548 - val_mean_squared_error: 0.0155
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 54s 116ms/step - loss: 0.7404 - mean_squared_error: 0.0094 - val_loss: 0.7547 - val_mean_squared_error: 0.0154
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0008153726346790791.
# 0.02128582303141144
# 0.015411280682089091
# 0.09804846748948097
# 0.08045646744066848

# %% [markdown]
# # Run a 10 Epoch Test
# We will run a similar test to optimize regularization, number of neurons, and dropout on the cluster, but we will run a quick test to make sure everything else works here too.

# %%
# Model name and create resnet
# model_name = "small_resnet_" + datetime.now().strftime("%m-%d-%Y_%H:%M:%S")
# print("Model name:", model_name)
# os.mkdir(model_name)
# os.mkdir(model_name + "_new")
batch_size = 128
small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


# Scheduler taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
s = np.concatenate((np.linspace(0, 0.1, 16)[1:], np.linspace(0.1, 0.005, 16)[1:], np.linspace(0, 0.005, 7)[-1:1:-1]))
n = len(s)
def schedule_outer(epoch, lr):
    if i > n:
        return lr * 0.96
    else:
        return s[i]
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

def schedule_inner(epoch, lr):
    return lr * 0.96
lr_scheduler_inner = tf.keras.callbacks.LearningRateScheduler(schedule_inner, verbose=1)


lr_reduce = keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_squared_error', factor=0.1, patience=1, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)


n_epochs = 10
hists1 = []
hists2 = []

for i in range(n_epochs):
    fhat_model.trainable = True
    fhat_model.summary()
    hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=1, batch_size=batch_size, 
                                 validation_data=(x_test, y_test_old / 10.), shuffle=False,
                                 callbacks=[lr_scheduler_outer,]))

    model = keras.Sequential()
    model.add(fhat_model.layers[0])
    fhat_model.trainable = False
    
    top2 = keras.models.Sequential([
        keras.layers.Dense(128, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(64, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation='sigmoid', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001))
    ], name='w_hat')
    
    model.add(top2)

    model.compile(optimizer=keras.optimizers.SGD(momentum=0.9),
                  loss=keras.losses.BinaryCrossentropy(),
                  metrics=[keras.metrics.MeanSquaredError()])
    model.summary()

    hists2.append(model.fit(x=x_train, y=y_train_old / 10., epochs=5, batch_size=batch_size, shuffle=False,
                            validation_data=(x_test, y_test_old / 10.), callbacks=[lr_scheduler_inner, lr_reduce,]))

total_hist1 = dict()
total_hist2 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
for key in hists2[0].history.keys():
    current_values = [] 
    for hist_dict in hists2:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist2[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist2['loss'], label='train')
ax[0].plot(total_hist2['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist2['mean_squared_error'], label='train')
ax[1].plot(total_hist2['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()

print(mse(fhat_model.predict(x_test), y_test_old / 10.))
print(mse(model.predict(x_test), y_test_old / 10.))

print(mae(fhat_model.predict(x_test), y_test_old / 10.))
print(mae(model.predict(x_test), y_test_old / 10.))
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006666666666666667.
# 469/469 [==============================] - 140s 295ms/step - loss: 0.8836 - mean_squared_error: 0.2341 - binary_accuracy: 0.5861 - val_loss: 0.8719 - val_mean_squared_error: 0.0622 - val_binary_accuracy: 0.0973
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 112ms/step - loss: 0.8175 - mean_squared_error: 0.0408 - val_loss: 0.7941 - val_mean_squared_error: 0.0312
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7697 - mean_squared_error: 0.0207 - val_loss: 0.7942 - val_mean_squared_error: 0.0313
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.0009215999394655228.
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.00088473591953516.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7673 - mean_squared_error: 0.0198 - val_loss: 0.7912 - val_mean_squared_error: 0.0302
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.000849346462637186.
# 469/469 [==============================] - 54s 115ms/step - loss: 0.7671 - mean_squared_error: 0.0197 - val_loss: 0.7906 - val_mean_squared_error: 0.0300
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000815372597426176.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7667 - mean_squared_error: 0.0196 - val_loss: 0.7904 - val_mean_squared_error: 0.0299
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 8.153726230375469e-05.
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.013333333333333334.
# 469/469 [==============================] - 139s 296ms/step - loss: 0.7583 - mean_squared_error: 0.1799 - binary_accuracy: 0.7260 - val_loss: 0.7479 - val_mean_squared_error: 0.0132 - val_binary_accuracy: 0.0978
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 58s 120ms/step - loss: 0.7969 - mean_squared_error: 0.0327 - val_loss: 0.7684 - val_mean_squared_error: 0.0212
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 54s 116ms/step - loss: 0.7430 - mean_squared_error: 0.0104 - val_loss: 0.7689 - val_mean_squared_error: 0.0215
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.0009215999394655228.
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.00088473591953516.
# 469/469 [==============================] - 53s 114ms/step - loss: 0.7414 - mean_squared_error: 0.0098 - val_loss: 0.7669 - val_mean_squared_error: 0.0207
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.000849346462637186.
# 469/469 [==============================] - 55s 117ms/step - loss: 0.7411 - mean_squared_error: 0.0097 - val_loss: 0.7669 - val_mean_squared_error: 0.0207
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 8.493464556522668e-05.
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 8.153726113960147e-05.
# 469/469 [==============================] - 54s 114ms/step - loss: 0.7411 - mean_squared_error: 0.0097 - val_loss: 0.7670 - val_mean_squared_error: 0.0208
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 8.15372623037547e-06.
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.02.
# 469/469 [==============================] - 134s 286ms/step - loss: 0.7399 - mean_squared_error: 0.1729 - binary_accuracy: 0.7381 - val_loss: 0.7366 - val_mean_squared_error: 0.0087 - val_binary_accuracy: 0.0979
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7822 - mean_squared_error: 0.0267 - val_loss: 0.7642 - val_mean_squared_error: 0.0199
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7354 - mean_squared_error: 0.0078 - val_loss: 0.7599 - val_mean_squared_error: 0.0183
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7339 - mean_squared_error: 0.0073 - val_loss: 0.7592 - val_mean_squared_error: 0.0180
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7332 - mean_squared_error: 0.0070 - val_loss: 0.7568 - val_mean_squared_error: 0.0170
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 132s 281ms/step - loss: 0.7327 - mean_squared_error: 0.0069 - val_loss: 0.7564 - val_mean_squared_error: 0.0169
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.02666666666666667.
# 469/469 [==============================] - 134s 286ms/step - loss: 0.7321 - mean_squared_error: 0.1697 - binary_accuracy: 0.7442 - val_loss: 0.7437 - val_mean_squared_error: 0.0110 - val_binary_accuracy: 0.0979
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 113ms/step - loss: 0.7783 - mean_squared_error: 0.0250 - val_loss: 0.7541 - val_mean_squared_error: 0.0161
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7329 - mean_squared_error: 0.0067 - val_loss: 0.7520 - val_mean_squared_error: 0.0153
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7315 - mean_squared_error: 0.0063 - val_loss: 0.7507 - val_mean_squared_error: 0.0148
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7310 - mean_squared_error: 0.0061 - val_loss: 0.7499 - val_mean_squared_error: 0.0145
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7306 - mean_squared_error: 0.0060 - val_loss: 0.7498 - val_mean_squared_error: 0.0144
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0008153726346790791.
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.03333333333333333.
# 469/469 [==============================] - 134s 285ms/step - loss: 0.7269 - mean_squared_error: 0.1672 - binary_accuracy: 0.7506 - val_loss: 0.7527 - val_mean_squared_error: 0.0138 - val_binary_accuracy: 0.0980
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 112ms/step - loss: 0.7769 - mean_squared_error: 0.0245 - val_loss: 0.7577 - val_mean_squared_error: 0.0179
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7335 - mean_squared_error: 0.0071 - val_loss: 0.7516 - val_mean_squared_error: 0.0153
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7322 - mean_squared_error: 0.0067 - val_loss: 0.7494 - val_mean_squared_error: 0.0144
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7313 - mean_squared_error: 0.0064 - val_loss: 0.7474 - val_mean_squared_error: 0.0135
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7310 - mean_squared_error: 0.0062 - val_loss: 0.7463 - val_mean_squared_error: 0.0130
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.04.
# 469/469 [==============================] - 133s 284ms/step - loss: 0.7260 - mean_squared_error: 0.1665 - binary_accuracy: 0.7516 - val_loss: 0.7456 - val_mean_squared_error: 0.0114 - val_binary_accuracy: 0.0979
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 112ms/step - loss: 0.7758 - mean_squared_error: 0.0236 - val_loss: 0.7654 - val_mean_squared_error: 0.0206
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 54s 115ms/step - loss: 0.7340 - mean_squared_error: 0.0070 - val_loss: 0.7600 - val_mean_squared_error: 0.0185
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 55s 117ms/step - loss: 0.7327 - mean_squared_error: 0.0066 - val_loss: 0.7574 - val_mean_squared_error: 0.0174
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 53s 114ms/step - loss: 0.7320 - mean_squared_error: 0.0063 - val_loss: 0.7552 - val_mean_squared_error: 0.0165
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.7316 - mean_squared_error: 0.0061 - val_loss: 0.7533 - val_mean_squared_error: 0.0157
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.04666666666666667.
# 469/469 [==============================] - 137s 292ms/step - loss: 0.7254 - mean_squared_error: 0.1657 - binary_accuracy: 0.7527 - val_loss: 0.7536 - val_mean_squared_error: 0.0141 - val_binary_accuracy: 0.0980
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 56s 116ms/step - loss: 0.7793 - mean_squared_error: 0.0252 - val_loss: 0.7578 - val_mean_squared_error: 0.0175
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 54s 116ms/step - loss: 0.7339 - mean_squared_error: 0.0070 - val_loss: 0.7527 - val_mean_squared_error: 0.0155
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 54s 116ms/step - loss: 0.7328 - mean_squared_error: 0.0067 - val_loss: 0.7516 - val_mean_squared_error: 0.0151
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.7319 - mean_squared_error: 0.0064 - val_loss: 0.7514 - val_mean_squared_error: 0.0150
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7317 - mean_squared_error: 0.0062 - val_loss: 0.7507 - val_mean_squared_error: 0.0147
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.05333333333333334.
# 469/469 [==============================] - 133s 284ms/step - loss: 0.7268 - mean_squared_error: 0.1655 - binary_accuracy: 0.7530 - val_loss: 0.7572 - val_mean_squared_error: 0.0147 - val_binary_accuracy: 0.0980
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 113ms/step - loss: 0.7780 - mean_squared_error: 0.0246 - val_loss: 0.7588 - val_mean_squared_error: 0.0181
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.7352 - mean_squared_error: 0.0075 - val_loss: 0.7538 - val_mean_squared_error: 0.0160
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7336 - mean_squared_error: 0.0069 - val_loss: 0.7536 - val_mean_squared_error: 0.0159
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7330 - mean_squared_error: 0.0067 - val_loss: 0.7521 - val_mean_squared_error: 0.0152
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008153726756572723.
# 469/469 [==============================] - 54s 115ms/step - loss: 0.7326 - mean_squared_error: 0.0065 - val_loss: 0.7510 - val_mean_squared_error: 0.0147
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.060000000000000005.
# 469/469 [==============================] - 135s 289ms/step - loss: 0.7252 - mean_squared_error: 0.1642 - binary_accuracy: 0.7537 - val_loss: 0.7777 - val_mean_squared_error: 0.0219 - val_binary_accuracy: 0.0980
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 113ms/step - loss: 0.7795 - mean_squared_error: 0.0253 - val_loss: 0.7656 - val_mean_squared_error: 0.0212
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7354 - mean_squared_error: 0.0077 - val_loss: 0.7619 - val_mean_squared_error: 0.0196
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7338 - mean_squared_error: 0.0071 - val_loss: 0.7608 - val_mean_squared_error: 0.0191
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 54s 115ms/step - loss: 0.7329 - mean_squared_error: 0.0068 - val_loss: 0.7626 - val_mean_squared_error: 0.0198
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.000849346537142992.
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0008153726533055305.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7325 - mean_squared_error: 0.0066 - val_loss: 0.7595 - val_mean_squared_error: 0.0185
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.06666666666666667.
# 469/469 [==============================] - 135s 287ms/step - loss: 0.7266 - mean_squared_error: 0.1638 - binary_accuracy: 0.7541 - val_loss: 0.8129 - val_mean_squared_error: 0.0340 - val_binary_accuracy: 0.0980
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 270,593
# Non-trainable params: 23,558,528
# _________________________________________________________________
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 113ms/step - loss: 0.7829 - mean_squared_error: 0.0268 - val_loss: 0.7559 - val_mean_squared_error: 0.0166
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7347 - mean_squared_error: 0.0073 - val_loss: 0.7518 - val_mean_squared_error: 0.0150
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7333 - mean_squared_error: 0.0068 - val_loss: 0.7510 - val_mean_squared_error: 0.0146
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7326 - mean_squared_error: 0.0065 - val_loss: 0.7509 - val_mean_squared_error: 0.0145
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.000849346537142992.
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0008153726533055305.
# 469/469 [==============================] - 53s 113ms/step - loss: 0.7323 - mean_squared_error: 0.0064 - val_loss: 0.7502 - val_mean_squared_error: 0.0143
# 0.02992621427626019
# 0.014264640494836453
# 0.10937449763568118
# 0.07365174808915703

# %% [markdown]
# # Two More Tests Before the Cluster
# Before moving to the cluster, we should update to model checkpointing AND add multiple validation sets so we can actually compare what we want to compare. We will just test this for a couple epochs to make sure it works.

# %%
################## Model saving logisticcs
base_name = datetime.now().strftime("%m-%d-%Y_%H:%M:%S")
print("Time:", base_name)
os.mkdir("fhat_" + base_name)
os.mkdir("w_new_h_hat_" + base_name)
batch_size = 128


################## Callbacks
save_model1 = keras.callbacks.ModelCheckpoint(
    "fhat_" + base_name, monitor='val_mean_squared_error', verbose=1, save_best_only=True)

save_model2 = keras.callbacks.ModelCheckpoint(
    "w_new_h_hat_" + base_name, monitor='val_mean_squared_error', verbose=1, save_best_only=True)

s = np.concatenate((np.linspace(0, 0.1, 16)[1:], np.linspace(0.1, 0.005, 16)[1:], np.linspace(0, 0.005, 7)[-1:1:-1]))
n = len(s)
def schedule_outer(epoch, lr):
    if i > n:
        return lr * 0.96
    else:
        return s[i]
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

def schedule_inner(epoch, lr):
    return lr * 0.96
lr_scheduler_inner = tf.keras.callbacks.LearningRateScheduler(schedule_inner, verbose=1)

lr_reduce = keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_squared_error', factor=0.1, patience=1, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
        
class AdditionalValidationSets(keras.callbacks.Callback):
    def __init__(self, validation_sets, verbose=0, batch_size=None):
        """
        From https://stackoverflow.com/questions/47731935/using-multiple-validation-sets-with-keras
        :param validation_sets:
        a list of 3-tuples (validation_data, validation_targets, validation_set_name)
        or 4-tuples (validation_data, validation_targets, sample_weights, validation_set_name)
        :param verbose:
        verbosity mode, 1 or 0
        :param batch_size:
        batch size to be used when evaluating on the additional datasets
        """
        super(AdditionalValidationSets, self).__init__()
        self.validation_sets = validation_sets
        for validation_set in self.validation_sets:
            if len(validation_set) not in [3, 4]:
                raise ValueError()
        self.epoch = []
        self.history = {}
        self.verbose = verbose
        self.batch_size = batch_size

    def on_train_begin(self, logs=None):
        self.epoch = []
        self.history = {}

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        self.epoch.append(epoch)

        # record the same values as History() as well
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        # evaluate on the additional validation sets
        for validation_set in self.validation_sets:
            if len(validation_set) == 3:
                validation_data, validation_targets, validation_set_name = validation_set
                sample_weights = None
            elif len(validation_set) == 4:
                validation_data, validation_targets, sample_weights, validation_set_name = validation_set
            else:
                raise ValueError()

            results = self.model.evaluate(x=validation_data,
                                          y=validation_targets,
                                          verbose=self.verbose,
                                          sample_weight=sample_weights,
                                          batch_size=self.batch_size)

            for metric, result in zip(self.model.metrics_names,results):
                valuename = validation_set_name + '_' + metric
                self.history.setdefault(valuename, []).append(result)
                if self.verbose:
                    print(valuename + ": " + str(result))
fhat_data = AdditionalValidationSets([(x_test, y_test_old / 10., 'p*_mse')], verbose=1, batch_size=batch_size)
ftilde_data = AdditionalValidationSets([(x_test, y_test, 'y_mse')], verbose=1, batch_size=batch_size)


################## Model creation
small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


################## Training loop
n_epochs = 2
hists1 = []
hists2 = []

for i in range(n_epochs):
    fhat_model.trainable = True
    hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=1, batch_size=batch_size, 
                                 validation_data=(x_test, y_test), 
                                 callbacks=[lr_scheduler_outer, save_model1, fhat_data,]))

    model = keras.Sequential()
    model.add(fhat_model.layers[0])
    fhat_model.trainable = False
    
    top2 = keras.models.Sequential([
        keras.layers.Dense(128, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(64, activation='tanh', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation='sigmoid', 
                           kernel_initializer=keras.initializers.RandomUniform(), 
                           kernel_regularizer=keras.regularizers.l2(0.001))
    ], name='w_hat')
    
    model.add(top2)

    model.compile(optimizer=keras.optimizers.SGD(momentum=0.9),
                  loss=keras.losses.BinaryCrossentropy(),
                  metrics=[keras.metrics.MeanSquaredError()])

    hists2.append(model.fit(x=x_train, y=y_train_old / 10., epochs=5, batch_size=batch_size,
                            validation_data=(x_test, y_test_old / 10.), 
                            callbacks=[lr_scheduler_inner, lr_reduce, save_model2, ftilde_data]))
    
    print(mse(fhat_model.predict(x_test), y_test_old / 10.))
    print(mse(model.predict(x_test), y_test_old / 10.))

    print(mae(fhat_model.predict(x_test), y_test_old / 10.))
    print(mae(model.predict(x_test), y_test_old / 10.))


################## Save results
total_hist1 = dict()
total_hist2 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
for key in hists2[0].history.keys():
    current_values = [] 
    for hist_dict in hists2:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist2[key] = current_values
    
json.dump(total_hist1, open("fhat_" + base_name + "/history.json", 'w'))
pickle.dump(total_hist1, open("fhat_" + base_name + "/history.pkl", 'wb'), pickle.HIGHEST_PROTOCOL)
json.dump(total_hist2, open("w_new_h_hat_" + base_name + "/history.json", 'w'))
pickle.dump(total_hist2, open("w_new_h_hat_" + base_name + "/history.pkl", 'wb'), pickle.HIGHEST_PROTOCOL)


################## Add some plots for good measure
fig, ax = plt.subplots(1, 2, figsize=(8,4))
ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(8,4))
ax[0].plot(total_hist2['loss'], label='train')
ax[0].plot(total_hist2['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[1].plot(total_hist2['mean_squared_error'], label='train')
ax[1].plot(total_hist2['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
ax.plot(total_hist1['p*_mse'], label='fhat')
ax.plot(total_hist2['val_mean_squared_error'], label='w_new * hhat')
ax.legend()
ax.set_title("p* Validation MSE")
ax.set_xlabel("Epochs")
plt.show()
# Out:
# Time: 05-21-2021_23:36:51
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006666666666666667.
# 469/469 [==============================] - 135s 284ms/step - loss: 0.8782 - mean_squared_error: 0.2313 - binary_accuracy: 0.5986 - val_loss: 0.7796 - val_mean_squared_error: 0.1877 - val_binary_accuracy: 0.7151
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.18771, saving model to fhat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: fhat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 8s 90ms/step - loss: -858992.8750 - mean_squared_error: 840075156579369877504.0000 - binary_accuracy: 0.0972
# p*_mse_loss: -858992.875
# p*_mse_mean_squared_error: 8.400751565793699e+20
# p*_mse_binary_accuracy: 0.09719999879598618
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 112ms/step - loss: 0.8179 - mean_squared_error: 0.0410 - val_loss: 0.7679 - val_mean_squared_error: 0.0199
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.01986, saving model to w_new_h_hat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: w_new_h_hat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 8s 90ms/step - loss: 0.7707 - mean_squared_error: 0.1838
# y_mse_loss: 0.7707386016845703
# y_mse_mean_squared_error: 0.183831587433815
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7660 - mean_squared_error: 0.0186 - val_loss: 0.7602 - val_mean_squared_error: 0.0168
#
# Epoch 00002: val_mean_squared_error improved from 0.01986 to 0.01683, saving model to w_new_h_hat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: w_new_h_hat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 7s 90ms/step - loss: 0.7626 - mean_squared_error: 0.1806
# y_mse_loss: 0.7626426815986633
# y_mse_mean_squared_error: 0.18056632578372955
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 52s 112ms/step - loss: 0.7622 - mean_squared_error: 0.0175 - val_loss: 0.7581 - val_mean_squared_error: 0.0160
#
# Epoch 00003: val_mean_squared_error improved from 0.01683 to 0.01604, saving model to w_new_h_hat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: w_new_h_hat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 7s 90ms/step - loss: 0.7618 - mean_squared_error: 0.1804
# y_mse_loss: 0.7618282437324524
# y_mse_mean_squared_error: 0.18035264313220978
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.008493465185165404.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7609 - mean_squared_error: 0.0172 - val_loss: 0.7583 - val_mean_squared_error: 0.0163
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.000849346537142992.
#
# Epoch 00004: val_mean_squared_error did not improve from 0.01604
# 79/79 [==============================] - 7s 91ms/step - loss: 0.7611 - mean_squared_error: 0.1803
# y_mse_loss: 0.7611233592033386
# y_mse_mean_squared_error: 0.18031761050224304
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0008153726533055305.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7601 - mean_squared_error: 0.0169 - val_loss: 0.7571 - val_mean_squared_error: 0.0158
#
# Epoch 00005: val_mean_squared_error improved from 0.01604 to 0.01576, saving model to w_new_h_hat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: w_new_h_hat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 7s 91ms/step - loss: 0.7602 - mean_squared_error: 0.1798
# y_mse_loss: 0.7602019309997559
# y_mse_mean_squared_error: 0.17977038025856018
# 0.018205737911819786
# 0.01576157318205602
# 0.09867885610863567
# 0.08856687414776535
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.013333333333333334.
# 469/469 [==============================] - 133s 283ms/step - loss: 0.7579 - mean_squared_error: 0.1795 - binary_accuracy: 0.7275 - val_loss: 0.7459 - val_mean_squared_error: 0.1749 - val_binary_accuracy: 0.7378
#
# Epoch 00001: val_mean_squared_error improved from 0.18771 to 0.17487, saving model to fhat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: fhat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 7s 90ms/step - loss: 0.6973 - mean_squared_error: 0.4688 - binary_accuracy: 0.0976
# p*_mse_loss: 0.6972578763961792
# p*_mse_mean_squared_error: 0.4687562882900238
# p*_mse_binary_accuracy: 0.09759999811649323
# Epoch 1/5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009599999785423278.
# 469/469 [==============================] - 54s 112ms/step - loss: 0.7897 - mean_squared_error: 0.0291 - val_loss: 0.7378 - val_mean_squared_error: 0.0084
#
# Epoch 00001: val_mean_squared_error improved from 0.01576 to 0.00844, saving model to w_new_h_hat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: w_new_h_hat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 7s 90ms/step - loss: 0.7402 - mean_squared_error: 0.1722
# y_mse_loss: 0.7402439713478088
# y_mse_mean_squared_error: 0.17215093970298767
# Epoch 2/5
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00921599954366684.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7425 - mean_squared_error: 0.0100 - val_loss: 0.7365 - val_mean_squared_error: 0.0081
#
# Epoch 00002: val_mean_squared_error improved from 0.00844 to 0.00814, saving model to w_new_h_hat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: w_new_h_hat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 7s 90ms/step - loss: 0.7386 - mean_squared_error: 0.1716
# y_mse_loss: 0.7386489510536194
# y_mse_mean_squared_error: 0.17161773145198822
# Epoch 3/5
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.008847359418869018.
# 469/469 [==============================] - 53s 112ms/step - loss: 0.7407 - mean_squared_error: 0.0096 - val_loss: 0.7365 - val_mean_squared_error: 0.0081
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.000884735956788063.
#
# Epoch 00003: val_mean_squared_error improved from 0.00814 to 0.00811, saving model to w_new_h_hat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: w_new_h_hat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 7s 90ms/step - loss: 0.7383 - mean_squared_error: 0.1715
# y_mse_loss: 0.7382786870002747
# y_mse_mean_squared_error: 0.17150430381298065
# Epoch 4/5
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0008493465185165405.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7403 - mean_squared_error: 0.0097 - val_loss: 0.7374 - val_mean_squared_error: 0.0085
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 8.493465138599278e-05.
#
# Epoch 00004: val_mean_squared_error did not improve from 0.00811
# 79/79 [==============================] - 7s 90ms/step - loss: 0.7399 - mean_squared_error: 0.1722
# y_mse_loss: 0.7398945093154907
# y_mse_mean_squared_error: 0.17221477627754211
# Epoch 5/5
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 8.153726812452077e-05.
# 469/469 [==============================] - 52s 111ms/step - loss: 0.7419 - mean_squared_error: 0.0094 - val_loss: 0.7360 - val_mean_squared_error: 0.0078
#
# Epoch 00005: val_mean_squared_error improved from 0.00811 to 0.00782, saving model to w_new_h_hat_05-21-2021_23:36:51
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: w_new_h_hat_05-21-2021_23:36:51/assets
# 79/79 [==============================] - 7s 90ms/step - loss: 0.7387 - mean_squared_error: 0.1716
# y_mse_loss: 0.7386652827262878
# y_mse_mean_squared_error: 0.17157122492790222
# 0.013153093021634803
# 0.007821270448221356
# 0.08022857202105224
# 0.054027827499806884
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-67fdbd977b4c> in <module>
#     186     total_hist2[key] = current_values
#     187
# --> 188 json.dump(total_hist1, open("fhat_" + base_name + "/history.json", 'w'))
#     189 pickle.dump(total_hist1, open("fhat_" + base_name + "/history.pkl", 'wb'), pickle.HIGHEST_PROTOCOL)
#     190 json.dump(total_hist2, open("w_new_h_hat_" + base_name + "/history.json", 'w'))
#
# ~/miniforge3/envs/tf/lib/python3.8/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~/miniforge3/envs/tf/lib/python3.8/json/encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# ~/miniforge3/envs/tf/lib/python3.8/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~/miniforge3/envs/tf/lib/python3.8/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/miniforge3/envs/tf/lib/python3.8/json/encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# ~/miniforge3/envs/tf/lib/python3.8/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type float32 is not JSON serializable

# %%
fhat_data.history # fix the code to use this instead
# Out:
# {'loss': [0.7579489350318909],
#  'mean_squared_error': [0.17948691546916962],
#  'binary_accuracy': [0.7274666428565979],
#  'val_loss': [0.7459040284156799],
#  'val_mean_squared_error': [0.1748659312725067],
#  'val_binary_accuracy': [0.7378000020980835],
#  'lr': [0.013333334],
#  'p*_mse_loss': [0.6972578763961792],
#  'p*_mse_mean_squared_error': [0.4687562882900238],
#  'p*_mse_binary_accuracy': [0.09759999811649323]}

# %%
################## Save results
total_hist1 = dict()
total_hist2 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
for key in hists2[0].history.keys():
    current_values = [] 
    for hist_dict in hists2:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist2[key] = current_values
    
json.dump(str(total_hist1), open("fhat_" + base_name + "/history.json", 'w'))
pickle.dump(total_hist1, open("fhat_" + base_name + "/history.pkl", 'wb'), pickle.HIGHEST_PROTOCOL)
json.dump(str(total_hist2), open("w_new_h_hat_" + base_name + "/history.json", 'w'))
pickle.dump(total_hist2, open("w_new_h_hat_" + base_name + "/history.pkl", 'wb'), pickle.HIGHEST_PROTOCOL)


################## Add some plots for good measure
fig, ax = plt.subplots(1, 2, figsize=(8,4))
ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(8,4))
ax[0].plot(total_hist2['loss'], label='train')
ax[0].plot(total_hist2['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[1].plot(total_hist2['mean_squared_error'], label='train')
ax[1].plot(total_hist2['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(4,4))
ax.plot(total_hist1['p*_mse_mean_squared_error'], label='fhat')
ax.plot(total_hist2['val_mean_squared_error'], label='w_new * hhat')
ax.legend()
ax.set_title("p* Validation MSE")
ax.set_xlabel("Epochs")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-52a7ad807bb3> in <module>
#      35
#      36 fig, ax = plt.subplots(figsize=(4,4))
# ---> 37 ax.plot(total_hist1['p*_mse_mean_squared_error'], label='fhat')
#      38 ax.plot(total_hist2['val_mean_squared_error'], label='w_new * hhat')
#      39 ax.legend()
#
# KeyError: 'p*_mse_mean_squared_error'

# %% [markdown]
# # Last Test: Check that Outer Schedule is Good
# We based the outer training loop on something found on the internet. Let's verify for the 35 epochs that they tested that it's good. Otherwise, tweak the schedule as required. In the for loop below, we try the following
# - Exponential decay at [0.99, 0.96, 0.90]
# - The schedule from the website
# - Fixed initial lr, reducing on plateau with factors of [1.5, 2, 10]
#
# We will test each of these for 30 epochs.
#
# #### It turns out it's too much memory for my laptop, will run on the cluster in the morning :)

# %%
batch_size = 128
small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


# Scheduler taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
s = np.concatenate((np.linspace(0, 0.1, 16)[1:], np.linspace(0.1, 0.005, 16)[1:], np.linspace(0, 0.005, 7)[-1:1:-1]))
n = len(s)
def schedule_outer(epoch, lr):
    if epoch > n:
        return lr * 0.96
    else:
        return s[epoch]
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

hists1 = []
hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=30, batch_size=batch_size, 
                             validation_data=(x_test, y_test_old / 10.), shuffle=False,
                             callbacks=[lr_scheduler_outer,]))

total_hist1 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()


############################################################################################################


small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


# Scheduler taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
def schedule_outer(epoch, lr):
    return lr * 0.99
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

hists1 = []
hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=30, batch_size=batch_size, 
                             validation_data=(x_test, y_test_old / 10.), shuffle=False,
                             callbacks=[lr_scheduler_outer,]))

total_hist1 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()


############################################################################################################


small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


# Scheduler taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
def schedule_outer(epoch, lr):
    return lr * 0.96
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

hists1 = []
hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=30, batch_size=batch_size, 
                             validation_data=(x_test, y_test_old / 10.), shuffle=False,
                             callbacks=[lr_scheduler_outer,]))

total_hist1 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()


############################################################################################################


small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()


# Scheduler taken from https://github.com/davidcpage/cifar10-fast/blob/master/experiments.ipynb
def schedule_outer(epoch, lr):
    return lr * 0.93
lr_scheduler_outer = tf.keras.callbacks.LearningRateScheduler(schedule_outer, verbose=1)

hists1 = []
hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=30, batch_size=batch_size, 
                             validation_data=(x_test, y_test_old / 10.), shuffle=False,
                             callbacks=[lr_scheduler_outer,]))

total_hist1 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()


############################################################################################################


small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

lr_reduce = keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_squared_error', factor=0.1, patience=1, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()

hists1 = []
hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=30, batch_size=batch_size, 
                             validation_data=(x_test, y_test_old / 10.), shuffle=False,
                             callbacks=[lr_reduce,]))

total_hist1 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()


############################################################################################################


small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

lr_reduce = keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_squared_error', factor=0.5, patience=1, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()

hists1 = []
hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=30, batch_size=batch_size, 
                             validation_data=(x_test, y_test_old / 10.), shuffle=False,
                             callbacks=[lr_reduce,]))

total_hist1 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()


############################################################################################################


small_resnet = tf.keras.applications.ResNet50V2(
    include_top=False, weights=None, input_tensor=None,
    input_shape=(32, 32, 1), pooling='max', classes=1,
    classifier_activation='sigmoid')

top1 = keras.models.Sequential([
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomUniform(), 
                       kernel_regularizer=keras.regularizers.l2(0.001))
], name='w_hat')

opt = keras.optimizers.SGD(momentum=0.9)

lr_reduce = keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_squared_error', factor=0.7, patience=1, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

# Construct model
fhat_model = keras.Sequential()
fhat_model.add(small_resnet)
fhat_model.add(top1)
fhat_model.compile(optimizer=opt,
                   loss=keras.losses.BinaryCrossentropy(),
                   metrics=[keras.metrics.MeanSquaredError(), 
                            keras.metrics.BinaryAccuracy()])
fhat_model.summary()

hists1 = []
hists1.append(fhat_model.fit(x=x_train, y=y_train, epochs=30, batch_size=batch_size, 
                             validation_data=(x_test, y_test_old / 10.), shuffle=False,
                             callbacks=[lr_reduce,]))

total_hist1 = dict()

for key in hists1[0].history.keys():
    current_values = [] 
    for hist_dict in hists1:
        hist_dict = hist_dict.history
        current_values += hist_dict[key]
    total_hist1[key] = current_values
    
fig, ax = plt.subplots(1, 2, figsize=(8,4))

ax[0].plot(total_hist1['loss'], label='train')
ax[0].plot(total_hist1['val_loss'], label='test')
ax[0].legend()
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")


ax[1].plot(total_hist1['mean_squared_error'], label='train')
ax[1].plot(total_hist1['val_mean_squared_error'], label='test')
ax[1].legend()
ax[1].set_title("Mean Squared Error")
ax[1].set_xlabel("Epochs")

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006666666666666667.
# 469/469 [==============================] - 136s 286ms/step - loss: 0.8719 - mean_squared_error: 0.2283 - binary_accuracy: 0.6038 - val_loss: 0.8277 - val_mean_squared_error: 0.0463 - val_binary_accuracy: 0.0978
# Epoch 2/30
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.013333333333333334.
# 469/469 [==============================] - 134s 285ms/step - loss: 0.7667 - mean_squared_error: 0.1831 - binary_accuracy: 0.7148 - val_loss: 0.7440 - val_mean_squared_error: 0.0111 - val_binary_accuracy: 0.0977
# Epoch 3/30
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.02.
# 469/469 [==============================] - 133s 284ms/step - loss: 0.7437 - mean_squared_error: 0.1741 - binary_accuracy: 0.7347 - val_loss: 0.7360 - val_mean_squared_error: 0.0079 - val_binary_accuracy: 0.0973
# Epoch 4/30
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.02666666666666667.
# 469/469 [==============================] - 135s 289ms/step - loss: 0.7333 - mean_squared_error: 0.1698 - binary_accuracy: 0.7432 - val_loss: 0.7385 - val_mean_squared_error: 0.0090 - val_binary_accuracy: 0.0974
# Epoch 5/30
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.03333333333333333.
# 469/469 [==============================] - 136s 289ms/step - loss: 0.7275 - mean_squared_error: 0.1673 - binary_accuracy: 0.7487 - val_loss: 0.7377 - val_mean_squared_error: 0.0085 - val_binary_accuracy: 0.0974
# Epoch 6/30
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.04.
# 469/469 [==============================] - 134s 286ms/step - loss: 0.7240 - mean_squared_error: 0.1656 - binary_accuracy: 0.7517 - val_loss: 0.7450 - val_mean_squared_error: 0.0108 - val_binary_accuracy: 0.0966
# Epoch 7/30
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.04666666666666667.
# 469/469 [==============================] - 135s 288ms/step - loss: 0.7253 - mean_squared_error: 0.1656 - binary_accuracy: 0.7520 - val_loss: 0.7474 - val_mean_squared_error: 0.0113 - val_binary_accuracy: 0.0977
# Epoch 8/30
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.05333333333333334.
# 469/469 [==============================] - 135s 288ms/step - loss: 0.7236 - mean_squared_error: 0.1643 - binary_accuracy: 0.7554 - val_loss: 0.7589 - val_mean_squared_error: 0.0159 - val_binary_accuracy: 0.0965
# Epoch 9/30
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.060000000000000005.
# 469/469 [==============================] - 134s 285ms/step - loss: 0.7241 - mean_squared_error: 0.1638 - binary_accuracy: 0.7550 - val_loss: 0.7633 - val_mean_squared_error: 0.0169 - val_binary_accuracy: 0.0965
# Epoch 10/30
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.06666666666666667.
# 469/469 [==============================] - 133s 283ms/step - loss: 0.7266 - mean_squared_error: 0.1639 - binary_accuracy: 0.7542 - val_loss: 0.7697 - val_mean_squared_error: 0.0180 - val_binary_accuracy: 0.0975
# Epoch 11/30
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.07333333333333333.
# 469/469 [==============================] - 133s 284ms/step - loss: 0.7257 - mean_squared_error: 0.1625 - binary_accuracy: 0.7569 - val_loss: 0.7761 - val_mean_squared_error: 0.0186 - val_binary_accuracy: 0.0977
# Epoch 12/30
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.08.
# 469/469 [==============================] - 133s 283ms/step - loss: 0.7280 - mean_squared_error: 0.1623 - binary_accuracy: 0.7576 - val_loss: 0.7917 - val_mean_squared_error: 0.0222 - val_binary_accuracy: 0.0979
# Epoch 13/30
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.08666666666666667.
# 469/469 [==============================] - 133s 283ms/step - loss: 0.7272 - mean_squared_error: 0.1605 - binary_accuracy: 0.7597 - val_loss: 0.8017 - val_mean_squared_error: 0.0271 - val_binary_accuracy: 0.0973
# Epoch 14/30
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.09333333333333334.
# 469/469 [==============================] - 133s 283ms/step - loss: 0.7328 - mean_squared_error: 0.1610 - binary_accuracy: 0.7591 - val_loss: 0.7890 - val_mean_squared_error: 0.0191 - val_binary_accuracy: 0.0971
# Epoch 15/30
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.1.
# 469/469 [==============================] - 133s 283ms/step - loss: 0.7362 - mean_squared_error: 0.1604 - binary_accuracy: 0.7604 - val_loss: 0.8020 - val_mean_squared_error: 0.0235 - val_binary_accuracy: 0.0977
# Epoch 16/30
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.09366666666666668.
# 469/469 [==============================] - 133s 283ms/step - loss: 0.7364 - mean_squared_error: 0.1580 - binary_accuracy: 0.7657 - val_loss: 0.8264 - val_mean_squared_error: 0.0302 - val_binary_accuracy: 0.0976
# Epoch 17/30
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.08733333333333335.
# 469/469 [==============================] - 133s 283ms/step - loss: 0.7297 - mean_squared_error: 0.1537 - binary_accuracy: 0.7742 - val_loss: 0.8264 - val_mean_squared_error: 0.0297 - val_binary_accuracy: 0.0973
# Epoch 18/30
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.081.
# 469/469 [==============================] - 135s 287ms/step - loss: 0.7272 - mean_squared_error: 0.1514 - binary_accuracy: 0.7752 - val_loss: 0.8450 - val_mean_squared_error: 0.0326 - val_binary_accuracy: 0.0977
# Epoch 19/30
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.07466666666666667.
# 469/469 [==============================] - 136s 289ms/step - loss: 0.7220 - mean_squared_error: 0.1476 - binary_accuracy: 0.7834 - val_loss: 0.8516 - val_mean_squared_error: 0.0353 - val_binary_accuracy: 0.0973
# Epoch 20/30
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.06833333333333334.
# 469/469 [==============================] - 135s 289ms/step - loss: 0.7108 - mean_squared_error: 0.1421 - binary_accuracy: 0.7930 - val_loss: 0.8878 - val_mean_squared_error: 0.0466 - val_binary_accuracy: 0.0971
# Epoch 21/30
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.062000000000000006.
# 469/469 [==============================] - 135s 289ms/step - loss: 0.7052 - mean_squared_error: 0.1385 - binary_accuracy: 0.7975 - val_loss: 0.9177 - val_mean_squared_error: 0.0530 - val_binary_accuracy: 0.0977
# Epoch 22/30
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.05566666666666667.
# 469/469 [==============================] - 136s 289ms/step - loss: 0.6919 - mean_squared_error: 0.1324 - binary_accuracy: 0.8085 - val_loss: 0.9876 - val_mean_squared_error: 0.0663 - val_binary_accuracy: 0.0967
# Epoch 23/30
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.04933333333333334.
# 469/469 [==============================] - 136s 290ms/step - loss: 0.6767 - mean_squared_error: 0.1255 - binary_accuracy: 0.8203 - val_loss: 1.0333 - val_mean_squared_error: 0.0703 - val_binary_accuracy: 0.0964
# Epoch 24/30
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.04300000000000001.
# 469/469 [==============================] - 137s 292ms/step - loss: 0.6591 - mean_squared_error: 0.1179 - binary_accuracy: 0.8336 - val_loss: 0.9882 - val_mean_squared_error: 0.0655 - val_binary_accuracy: 0.0968
# Epoch 25/30
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.03666666666666668.
# 469/469 [==============================] - 133s 284ms/step - loss: 0.6304 - mean_squared_error: 0.1071 - binary_accuracy: 0.8489 - val_loss: 1.1090 - val_mean_squared_error: 0.0899 - val_binary_accuracy: 0.0946
# Epoch 26/30
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.030333333333333337.
# 469/469 [==============================] - 135s 288ms/step - loss: 0.6034 - mean_squared_error: 0.0970 - binary_accuracy: 0.8640 - val_loss: 1.1671 - val_mean_squared_error: 0.0952 - val_binary_accuracy: 0.0948
# Epoch 27/30
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.024000000000000007.
# 469/469 [==============================] - 136s 289ms/step - loss: 0.5687 - mean_squared_error: 0.0839 - binary_accuracy: 0.8859 - val_loss: 1.2725 - val_mean_squared_error: 0.1018 - val_binary_accuracy: 0.0954
# Epoch 28/30
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.017666666666666678.
# 469/469 [==============================] - 144s 307ms/step - loss: 0.5378 - mean_squared_error: 0.0736 - binary_accuracy: 0.9005 - val_loss: 1.3662 - val_mean_squared_error: 0.1128 - val_binary_accuracy: 0.0960
# Epoch 29/30
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.011333333333333334.
# 469/469 [==============================] - 141s 301ms/step - loss: 0.5042 - mean_squared_error: 0.0619 - binary_accuracy: 0.9176 - val_loss: 1.3720 - val_mean_squared_error: 0.1023 - val_binary_accuracy: 0.0972
# Epoch 30/30
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.005.
# 469/469 [==============================] - 139s 297ms/step - loss: 0.4861 - mean_squared_error: 0.0562 - binary_accuracy: 0.9252 - val_loss: 1.4438 - val_mean_squared_error: 0.1040 - val_binary_accuracy: 0.0976
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23558528
# _________________________________________________________________
# w_hat (Sequential)           (None, 1)                 270593
# =================================================================
# Total params: 23,829,121
# Trainable params: 23,783,681
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009899999778717757.
# 469/469 [==============================] - 150s 313ms/step - loss: 0.8621 - mean_squared_error: 0.2239 - binary_accuracy: 0.6191 - val_loss: 0.7737 - val_mean_squared_error: 0.0226 - val_binary_accuracy: 0.0964
# Epoch 2/30
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.009800999946892262.
# 469/469 [==============================] - ETA: 0s - loss: 0.7532 - mean_squared_error: 0.1775 - binary_accuracy: 0.7288

# %%
# check L2 param, number of neurons in dense layer, and dropout rate on cluster
# Be sure to save the training histories so we can make plots later
# Be sure to add multiple validation sets too

# %% [markdown]
# # Training
# Test out distributed options for Tensorflow and saving/loading

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
mirrored_strategy = tf.distribute.MirroredStrategy()
